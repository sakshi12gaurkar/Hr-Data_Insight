# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#load the dataset 
df=pd.read_excel("../Asus/Downloads/HR data.xlsx")
df
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
#display the first few rows and basic info
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
#issing values in dataset
df.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# 0                             0
# 0.1                           0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# ...

# %%
#handle the missing value
df_cleaned=df.dropna()

# %%
df_cleaned
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
#generate descriptive stastics for the numerics columns
df.describe()
# Out:
#        Employee Number  Training Times Last Year       0     0.1          Age  \
# count      1470.000000               1470.000000  1470.0  1470.0  1470.000000
# mean       1024.865306                  2.799320    -2.0     0.0    36.923810
# std         602.024335                  1.289271     0.0     0.0     9.135373
# min           1.000000                  0.000000    -2.0     0.0    18.000000
# 25%         491.250000                  2.000000    -2.0     0.0    30.000000
# 50%        1020.500000                  3.000000    -2.0     0.0    36.000000
# 75%        1555.750000                  3.000000    -2.0     0.0    43.000000
# max        2068.000000                  6.000000    -2.0     0.0    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# ...

# %%
#rename Cf_age band column to age band
df.rename(columns={'CF_age band': 'age band'}, inplace=True)
df
# Out:
#      Attrition    Business Travel  age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely   35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently   45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely   35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently   25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely   25 - 34  Current Employees        R&D
# ...        ...                ...       ...                ...        ...
# 1465       Yes         Non-Travel   25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently   25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently   35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely  Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely  Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number  Gender  \
# ...

# %%
#rows gender is male and attrition is yes
df[(df.Attrition=='Yes')&(df.Gender=='Male')]
df
# Out:
#      Attrition    Business Travel  age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely   35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently   45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely   35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently   25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely   25 - 34  Current Employees        R&D
# ...        ...                ...       ...                ...        ...
# 1465       Yes         Non-Travel   25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently   25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently   35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely  Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely  Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number  Gender  \
# ...

# %%
df['Year Since Promotion']=df['Years At Company']-df['Years Since Last Promotion']

# %%
df
# Out:
#      Attrition    Business Travel  age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely   35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently   45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely   35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently   25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely   25 - 34  Current Employees        R&D
# ...        ...                ...       ...                ...        ...
# 1465       Yes         Non-Travel   25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently   25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently   35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely  Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely  Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number  Gender  \
# ...

# %%
#group the data by department and calculate average monthly income
df.groupby('Department')['Monthly Income'].mean()
# Out:
# Department
# HR       6654.507937
# R&D      6281.252862
# Sales    6959.172646
# Name: Monthly Income, dtype: float64

# %%
df.dtypes
# Out:
# Attrition                     object
# Business Travel               object
# age band                      object
# CF_attrition label            object
# Department                    object
# Education Field               object
# emp no                        object
# Employee Number                int64
# Gender                        object
# Job Role                      object
# Marital Status                object
# Over Time                     object
# Over18                        object
# Training Times Last Year       int64
# 0                              int64
# 0.1                            int64
# Age                            int64
# CF_current Employee            int64
# Daily Rate                     int64
# Distance From Home             int64
# Education                     object
# Employee Count                 int64
# Environment Satisfaction       int64
# Hourly Rate                    int64
# Job Involvement                int64
# ...

# %%
#average monthly income each job role
df.groupby('Job Role')['Monthly Income'].mean()
# Out:
# Job Role
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: Monthly Income, dtype: float64

# %%
#show the count of employees by Gender and Attrition
df.groupby('Gender')['Attrition'].count()
# Out:
# Gender
# Female    588
# Male      882
# Name: Attrition, dtype: int64

# %%
#show the total Monthly Income by Department and Gender
df.groupby(['Department','Gender'])['Monthly Income'].max()
# Out:
# Department  Gender
# HR          Female    19658
#             Male      19717
# R&D         Female    19973
#             Male      19999
# Sales       Female    19845
#             Male      19847
# Name: Monthly Income, dtype: int64

# %%
#Convert the A􀆩ri􀆟on column from object to numeric
df.Attrition= df['Attrition'].replace({'Yes':1, 'No':0})
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_13600\2753686192.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Attrition= df['Attrition'].replace({'Yes':1, 'No':0})
#       Attrition    Business Travel  age band CF_attrition label Department  \
# 0             1      Travel_Rarely   35 - 44       Ex-Employees      Sales
# 1             0  Travel_Frequently   45 - 54  Current Employees        R&D
# 2             1      Travel_Rarely   35 - 44       Ex-Employees        R&D
# 3             0  Travel_Frequently   25 - 34  Current Employees        R&D
# 4             0      Travel_Rarely   25 - 34  Current Employees        R&D
# ...         ...                ...       ...                ...        ...
# ...

# %%
#show the propor􀆟on of employees by Gender and A􀆩ri􀆟on.
df.groupby(['Gender', 'Attrition'])['Employee Count'].sum()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: Employee Count, dtype: int64

# %%
#Calculate the correla􀆟on matrix for the numeric
df.Age.unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
#Filter rows where Age is greater than 30 and Years At Company is less than 5
a = df[(df['Age'] > 30)&(df['Years At Company'] < 5)]
a
# Out:
#       Attrition    Business Travel age band CF_attrition label Department  \
# 2             1      Travel_Rarely  35 - 44       Ex-Employees        R&D
# 6             0      Travel_Rarely  Over 55  Current Employees        R&D
# 13            0      Travel_Rarely  25 - 34  Current Employees        R&D
# 19            0      Travel_Rarely  35 - 44  Current Employees        R&D
# 24            1      Travel_Rarely  25 - 34       Ex-Employees        R&D
# ...         ...                ...      ...                ...        ...
# 1456          1      Travel_Rarely  45 - 54       Ex-Employees      Sales
# 1457          1      Travel_Rarely  25 - 34       Ex-Employees      Sales
# 1461          1  Travel_Frequently  45 - 54       Ex-Employees        R&D
# 1462          1         Non-Travel  35 - 44       Ex-Employees        R&D
# 1464          1      Travel_Rarely  25 - 34       Ex-Employees      Sales
#
#      Education Field      emp no  Employee Number  Gender  \
# ...

# %%
(df['Marital Status'].value_counts())
# Out:
# Marital Status
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
#Plot a histogram of the Age column
sb.histplot(x=df.Age)
plt.show()

# %%
#Calculate the correla􀆟on matrix for the numerical columns
df.corr(numeric_only=True)
# Out:
#                             Attrition  Employee Number  \
# Attrition                    1.000000        -0.010577
# Employee Number             -0.010577         1.000000
# Training Times Last Year    -0.059478         0.023603
# 0                                 NaN              NaN
# 0.1                               NaN              NaN
# Age                         -0.159205        -0.010145
# CF_current Employee         -1.000000         0.010577
# Daily Rate                  -0.056652        -0.050990
# Distance From Home           0.077924         0.032916
# Employee Count                    NaN              NaN
# Environment Satisfaction    -0.103369         0.017621
# Hourly Rate                 -0.006846         0.035179
# Job Involvement             -0.130016        -0.006888
# Job Level                   -0.169105        -0.018519
# Job Satisfaction            -0.103481        -0.046247
# Monthly Income              -0.159840        -0.014829
# ...

# %%
#Show the correla􀆟on between Monthly Income and Job Sa􀆟sfac􀆟on
df[['Monthly Income','Job Satisfaction']].corr()
# Out:
#                   Monthly Income  Job Satisfaction
# Monthly Income          1.000000         -0.007157
# Job Satisfaction       -0.007157          1.000000

# %%
#Find out which employees have high monthly Incomes
a=df.groupby('Gender')['Monthly Income'].sum().nlargest(10)
a
# Out:
# Gender
# Male      5627608
# Female    3931701
# Name: Monthly Income, dtype: int64

# %%
#Find out how many Job roles are there
d = df['Job Role'].nunique()
d
# Out:
# 9

# %%
#Calculate the median of the Monthly Income column
h =  df['Monthly Income'].median()
h
# Out:
# 4919.0

# %%
max_working_years = df['Total Working Years'].max()
departments_with_max_years = df[df['Total Working Years'] == max_working_years]['Department']
f=("Maximum Total Working Years:", max_working_years)
e=("Department(s) with Maximum Total Working Years:", departments_with_max_years)

# %%
f
# Out:
# ('Maximum Total Working Years:', 40)

# %%
e
# Out:
# ('Department(s) with Maximum Total Working Years:',
#  126    R&D
#  595    R&D
#  Name: Department, dtype: object)

# %%
#Create a new column High Income that is True if Monthly Income is greater than the mean income otherwise false
mean_income = df['Monthly Income'].mean()
df['High Income'] = df['Monthly Income'] > mean_income
df
# Out:
#       Attrition    Business Travel  age band CF_attrition label Department  \
# 0             1      Travel_Rarely   35 - 44       Ex-Employees      Sales
# 1             0  Travel_Frequently   45 - 54  Current Employees        R&D
# 2             1      Travel_Rarely   35 - 44       Ex-Employees        R&D
# 3             0  Travel_Frequently   25 - 34  Current Employees        R&D
# 4             0      Travel_Rarely   25 - 34  Current Employees        R&D
# ...         ...                ...       ...                ...        ...
# 1465          1         Non-Travel   25 - 34       Ex-Employees        R&D
# 1466          1  Travel_Frequently   25 - 34       Ex-Employees        R&D
# 1467          1  Travel_Frequently   35 - 44       Ex-Employees      Sales
# 1468          1      Travel_Rarely  Under 25       Ex-Employees        R&D
# 1469          1      Travel_Rarely  Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number  Gender  \
# ...

# %%
max_rating = df['Performance Rating'].max()
departments_with_highest_rating = df[df['Performance Rating'] == max_rating]['Department']
h=("Departments with the highest performance rating:")
w=(departments_with_highest_rating)
h
# Out:
# 'Departments with the highest performance rating:'

# %%
w
# Out:
# 1         R&D
# 6         R&D
# 7         R&D
# 8         R&D
# 21      Sales
#         ...
# 1465      R&D
# 1466      R&D
# 1467    Sales
# 1468      R&D
# 1469    Sales
# Name: Department, Length: 226, dtype: object

# %%
#Count the number of employees for each educa􀆟on
(df['Education'].value_counts())
# Out:
# Education
# Bachelor's Degree    572
# Master's Degree      398
# Associates Degree    282
# High School          170
# Doctoral Degree       48
# Name: count, dtype: int64

# %%
#Calculate the average Job Sa􀆟sfac􀆟on for each educa􀆟on level
(df['Job Satisfaction'].mean())
# Out:
# 2.7285714285714286
